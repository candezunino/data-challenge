# %%
#Libraries
import pandas as pd
from collections import OrderedDict #to order the dictionary like the given example
import csv,json

# %%
#Use of pandas to visualize data in a friendly format
url='../db/landing/ecommerce/factory14/orders/839012383812.csv'

df=pd.read_csv(url)
df_columns=df.rename(columns={'_job_batch_id': 'daton_user_id', '_job_batch_runtime': 'daton_batch_runtime','_job_user_id':'daton_batch_id'})

df_columns
# Out:
#    daton_user_id  daton_batch_runtime  daton_batch_id  \
# 0            584        1630008352895             980
# 1            585        1630008352895             980
#
#                  admin_graphql_api_id  app_id  \
# 0  gid://ecommerce/Order/324000907291  580111
# 1  gid://ecommerce/Order/323187081243  580111
#
#                                      billing_address      browser_ip  \
# 0  [{"first_name":"David","address1":"14 Foxwood ...   108.46.161.60
# 1  [{"first_name":"Ramesh","address1":"Level 28, ...  210.10.226.130
#
#    buyer_accepts_marketing  cancel_reason  cancelled_at  ...  \
# 0                     True            NaN           NaN  ...
# 1                     True            NaN           NaN  ...
#
#                               token  total_discounts total_line_items_price  \
# 0  0a2451c04db76d570c07698b12deaeb3              0.0                  499.0
# 1  42960f87ca9b8d6ad5b93a17ec8c8abe              0.0                  499.0
#
#   total_price total_price_usd  total_tax total_weight  \
# 0       499.0          382.25       0.00            0
# 1       499.0          382.25      45.36            0
#
#                                         transactions           updated_at  \
# 0  [{"id":3.77738559515E11,"order_id":3.240009072...  2018-04-04T20:36:58
# 1  [{"id":3.76813387803E11,"order_id":3.231870812...  2018-04-16T19:42:40
#
#      user_id
# 0  435234134
# 1  124312312
#
# [2 rows x 67 columns]

# %%
url_csv='../db/landing/ecommerce/factory14/orders/839012383812.csv'
url_json='../extracts/839012383812_json.json'

result=OrderedDict()
i=0

#Open CSV file. Only Read access.
with open(url_csv,'r') as csvFile:
    reader = csv.DictReader(csvFile)
    
    #Open TXT file. Write access. It starts appending the dictionaries in the first iteration.
    with open(url_json,'w') as jsonFile:
        for row in reader:
            #Removes the metadata and saves it in a new index with the names that we need (the cols should always be the same).
            ## I use pop so the data_raw can have data of the rest of the columns, without the metadata
            ##it doesn't matter if the columns change.
            result["daton_user_id"] = row.pop('_job_batch_id')
            result["daton_batch_runtime"] = row.pop('_job_batch_runtime')
            result["daton_batch_id"] = row.pop('_job_user_id')
            result["creation_ts"] = row.pop('updated_at')
            result["data_raw"] = row
 
            #Order the dictionary so it can be like the example
            result.move_to_end('data_raw',last=False)
            dict_result=dict(result)
            
            #Adding [] so it can be exported later in pandas.
            if i==0:
                jsonFile.write('[') 
        
            #Add the comma before the second iteration to separate the dict so the last one doesn't have one
            if i:
                jsonFile.write(',\n') 
            i=+1
            jsonFile.write(json.dumps(dict_result, indent=4))
            
        jsonFile.write(']')

# %%
#import pyspark

# %%
#json_df = spark.read.json("../extracts/839012383812_json.txt", multiLine=True,) 
#json_df.printSchema()

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-e1ba6623a3f8> in <module>
#       2 # load data using Python JSON module
#       3 with open('../extracts/839012383812_json.json','r') as f:
# ----> 4     data = json.loads(f.read())
#       5 # Flatten data
#       6 df_nested_list = pd.json_normalize(data, record_path =['students'])
#
# ~/opt/miniconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/miniconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 71 column 2 (char 8006)

# %%
df2 = pd.read_json('../extracts/839012383812_json.json')
df2.head()
# read the entire file into a python array
#data = [json.loads(line) for line in open('../extracts/839012383812_json.json', 'r')]
# Out:
#                                             data_raw  daton_user_id  \
# 0  {'admin_graphql_api_id': 'gid://ecommerce/Orde...            584
# 1  {'admin_graphql_api_id': 'gid://ecommerce/Orde...            585
#
#    daton_batch_runtime  daton_batch_id          creation_ts
# 0        1630008352895             980  2018-04-04T20:36:58
# 1        1630008352895             980  2018-04-16T19:42:40

# %%
# load data using Python JSON module
with open('../extracts/839012383812_json.json','r') as f:
    data = json.loads(f.read())
    
# Normalizing data
df = pd.json_normalize(
    data, 
    meta=[
        ['data_raw', 'admin_graphql_api_id']
    ]
)
df.head()
# Out:
#   daton_user_id daton_batch_runtime daton_batch_id          creation_ts  \
# 0           584       1630008352895            980  2018-04-04T20:36:58
# 1           585       1630008352895            980  2018-04-16T19:42:40
#
#         data_raw.admin_graphql_api_id data_raw.app_id  \
# 0  gid://ecommerce/Order/324000907291          580111
# 1  gid://ecommerce/Order/323187081243          580111
#
#                             data_raw.billing_address data_raw.browser_ip  \
# 0  [{"first_name":"David","address1":"14 Foxwood ...       108.46.161.60
# 1  [{"first_name":"Ramesh","address1":"Level 28, ...      210.10.226.130
#
#   data_raw.buyer_accepts_marketing data_raw.cancel_reason  ... data_raw.test  \
# 0                             True                         ...         False
# 1                             True                         ...         False
#
#                      data_raw.token data_raw.total_discounts  \
# 0  0a2451c04db76d570c07698b12deaeb3                      0.0
# 1  42960f87ca9b8d6ad5b93a17ec8c8abe                      0.0
#
#   data_raw.total_line_items_price data_raw.total_price  \
# 0                           499.0                499.0
# 1                           499.0                499.0
#
#   data_raw.total_price_usd data_raw.total_tax data_raw.total_weight  \
# 0                   382.25                0.0                     0
# 1                   382.25              45.36                     0
#
#                                data_raw.transactions data_raw.user_id
# 0  [{"id":3.77738559515E11,"order_id":3.240009072...        435234134
# 1  [{"id":3.76813387803E11,"order_id":3.231870812...        124312312
#
# [2 rows x 67 columns]
